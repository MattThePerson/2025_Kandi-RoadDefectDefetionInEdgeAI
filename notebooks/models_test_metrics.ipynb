# %% [markdown]
# # Computing and Saving Test Metrics for Trained Models

# %%
# NOTE: run only once!
import os
os.chdir('..')

# %%
from pathlib import Path
import time
import pickle
import shutil
import polars as pl

from ultralytics import YOLO # type: ignore
from ultralytics import settings
from ultralytics.utils import metrics

# %%
PURPLE = "\033[0;35m"
END = "\033[0m"

# %%
# YOLO setup

# Set datasets (root) directory path
YAML_FILE =     Path("./YAML/test_PP_matti.yaml") # NOTE: change if needed
DATASETS_DIR =  Path("A:\\datasets\\kandi")       # NOTE: change if needed
RUNS_DIR =      Path("./ultralytics/runs")
WEIGHTS_DIR =   Path("./ultralytics/weights")

if not DATASETS_DIR.exists():
    raise FileNotFoundError(f"Please set path to existing folder. Current doesn't exist: '{DATASETS_DIR.resolve()}'")
if not YAML_FILE.exists():
    raise FileNotFoundError(f"Please set path to existing YAML file. Current doesn't exist: '{YAML_FILE.resolve()}'")

# YOLO settings
settings.reset() # resets YOLO settings
settings.update({
    "datasets_dir": str(DATASETS_DIR),
    "runs_dir":     str(RUNS_DIR),
    "weights_dir":  str(WEIGHTS_DIR),
})
# settings

# %%
# Get model paths
filters = [
    # 'long_runs',
    # '150ep',
    # 'normal',
    # "bch_32",
]
run_paths = sorted(
    Path('runs_puhti').rglob('best.pt'),
    key=lambda obj: str(obj),
)
run_paths = [ p.parent.parent for p in run_paths ]
for f in filters:
    run_paths = [ p for p in run_paths if f in str(p) ]
print("number of runs selected:", len(run_paths))
# Out:
# number of runs selected: 30

# %% [markdown]
# ### STEP 1: compute metrics

# %%
# RUN: Compute metrics for test set
TEST_METRICS_FOLDER = "test_split_metrics"

REDO = True
for i, run_path in enumerate(run_paths):
    model_path = run_path / "weights/best.pt"
    name = str(run_path).replace("\\", "/")
    print(f"  [{i+1:>2}/{len(run_paths)}] VALIDATING: \"{PURPLE}{name}{END}\"")
    
    # paths and check
    results_dir = run_path / TEST_METRICS_FOLDER
    results_pkl = results_dir / "metrics.pkl"
    if results_pkl.exists() and not REDO:
        print('  ... skipping')
        continue
    
    # validate
    start = time.time()
    model = YOLO(model_path)
    results: metrics.DetMetrics = model.val(
        data = str(YAML_FILE),
        split = "test",
        task = "detect",
        project = run_path,
        name = TEST_METRICS_FOLDER,
    )
    print("  ... took {:.1f} sec".format(time.time()-start))
    
    # save pickle
    results_pkl.parent.mkdir(exist_ok=True)
    print(f"pickling results to: '{results_pkl}'")
    with open(results_pkl, "wb") as f:
        pickle.dump(results, f)
    
    # move saved images to desired dir
    matches = list(Path(RUNS_DIR).rglob(f"*{run_path}/{TEST_METRICS_FOLDER}"))
    if len(matches) == 0:
        raise FileExistsError(f"cant find images generated by .val().")
    images_path = matches[0]
    new_images_path = Path("./") / images_path.relative_to(f"{RUNS_DIR}/detect") / "images"
    print('moving images dir to:', new_images_path)
    if not new_images_path.exists():
        shutil.move(images_path, new_images_path)
# Out:
#   [ 1/30] VALIDATING: "runs_puhti/long_runs/150ep_bch_32"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 1.21.1 ms, read: 1.80.5 MB/s, size: 66.2 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 4.3it/s 55.9s<0.1s
#                    all       3840       5416      0.644      0.516      0.575      0.299
#                    D00       1339       2615      0.657      0.521      0.569      0.318
#                    D10        743       1087      0.625      0.512      0.562      0.284
#                    D20        873       1086      0.689      0.623      0.672      0.365
#                    D40        357        628      0.603      0.408      0.495      0.228
# Speed: 5.4ms preprocess, 3.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_bch_32\test_split_metrics5
#   ... took 88.8 sec
# pickling results to: 'runs_puhti\long_runs\150ep_bch_32\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_bch_32\test_split_metrics\images
#   [ 2/30] VALIDATING: "runs_puhti/long_runs/150ep_bch_8"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.30.0 ms, read: 355.4749.8 MB/s, size: 353.0 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 7.7it/s 31.3s<0.1s
#                    all       3840       5416       0.62      0.515      0.559      0.291
#                    D00       1339       2615      0.618      0.519       0.55      0.305
#                    D10        743       1087      0.588      0.518      0.546       0.27
#                    D20        873       1086      0.691      0.615      0.669       0.37
#                    D40        357        628      0.584      0.408      0.469      0.219
# Speed: 1.1ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_bch_8\test_split_metrics
#   ... took 55.1 sec
# pickling results to: 'runs_puhti\long_runs\150ep_bch_8\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_bch_8\test_split_metrics\images
#   [ 3/30] VALIDATING: "runs_puhti/long_runs/150ep_crop"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.30.0 ms, read: 4.12.1 MB/s, size: 66.5 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 7.5it/s 31.9s<0.1s
#                    all       3840       5416      0.641      0.523      0.568      0.294
#                    D00       1339       2615       0.64      0.529      0.566      0.317
#                    D10        743       1087      0.614      0.532      0.567      0.279
#                    D20        873       1086      0.687      0.634      0.665      0.361
#                    D40        357        628      0.622      0.398      0.473      0.218
# Speed: 1.2ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_crop\test_split_metrics
#   ... took 66.4 sec
# pickling results to: 'runs_puhti\long_runs\150ep_crop\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_crop\test_split_metrics\images
#   [ 4/30] VALIDATING: "runs_puhti/long_runs/150ep_degrees"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.30.0 ms, read: 57.590.5 MB/s, size: 422.7 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.2it/s 29.4ss<0.1s
#                    all       3840       5416      0.612        0.5      0.543      0.266
#                    D00       1339       2615       0.61      0.514      0.551      0.289
#                    D10        743       1087      0.566      0.492        0.5       0.22
#                    D20        873       1086      0.679      0.591      0.654      0.343
#                    D40        357        628      0.594      0.402      0.466       0.21
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_degrees\test_split_metrics
#   ... took 53.8 sec
# pickling results to: 'runs_puhti\long_runs\150ep_degrees\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_degrees\test_split_metrics\images
#   [ 5/30] VALIDATING: "runs_puhti/long_runs/150ep_flipup"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.30.1 ms, read: 69.383.8 MB/s, size: 238.8 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 7.7it/s 31.1s<0.1s
#                    all       3840       5416      0.631      0.511      0.565      0.293
#                    D00       1339       2615      0.628       0.51      0.562      0.314
#                    D10        743       1087       0.61       0.52      0.572      0.287
#                    D20        873       1086      0.692      0.626      0.669      0.365
#                    D40        357        628      0.592      0.389      0.459      0.206
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_flipup\test_split_metrics
#   ... took 61.6 sec
# pickling results to: 'runs_puhti\long_runs\150ep_flipup\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_flipup\test_split_metrics\images
#   [ 6/30] VALIDATING: "runs_puhti/long_runs/150ep_hsv"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 237.737.0 MB/s, size: 229.0 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.5it/s 28.1s<0.1ss
#                    all       3840       5416      0.646      0.522      0.569      0.293
#                    D00       1339       2615      0.634      0.524      0.562      0.313
#                    D10        743       1087      0.623      0.522      0.566       0.28
#                    D20        873       1086      0.688      0.633      0.674      0.365
#                    D40        357        628      0.638      0.408      0.474      0.215
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_hsv\test_split_metrics
#   ... took 51.2 sec
# pickling results to: 'runs_puhti\long_runs\150ep_hsv\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_hsv\test_split_metrics\images
#   [ 7/30] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_320"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 465.4773.2 MB/s, size: 532.7 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 11.1it/s 21.7s0.2ss
#                    all       3840       5416      0.571      0.429      0.449      0.222
#                    D00       1339       2615      0.558      0.414      0.422       0.22
#                    D10        743       1087      0.531      0.455      0.452      0.218
#                    D20        873       1086       0.62      0.552      0.584      0.309
#                    D40        357        628      0.576      0.294      0.338      0.142
# Speed: 0.2ms preprocess, 1.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_imgsz_320\test_split_metrics
#   ... took 44.6 sec
# pickling results to: 'runs_puhti\long_runs\150ep_imgsz_320\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_imgsz_320\test_split_metrics\images
#   [ 8/30] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_400"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 806.4741.2 MB/s, size: 449.0 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 11.4it/s 21.1s0.2ss
#                    all       3840       5416      0.611      0.483      0.517      0.258
#                    D00       1339       2615      0.595      0.449      0.479      0.256
#                    D10        743       1087      0.564      0.512      0.527      0.256
#                    D20        873       1086      0.652      0.601      0.637       0.34
#                    D40        357        628      0.632      0.371      0.423      0.181
# Speed: 0.4ms preprocess, 1.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_imgsz_400\test_split_metrics
#   ... took 42.8 sec
# pickling results to: 'runs_puhti\long_runs\150ep_imgsz_400\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_imgsz_400\test_split_metrics\images
#   [ 9/30] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_480"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 506.5657.8 MB/s, size: 225.4 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 10.7it/s 22.5s<0.1s
#                    all       3840       5416      0.608      0.502      0.533      0.272
#                    D00       1339       2615      0.603      0.486      0.512      0.279
#                    D10        743       1087       0.58      0.518      0.539      0.269
#                    D20        873       1086      0.656      0.616      0.658      0.353
#                    D40        357        628      0.593      0.387      0.421      0.187
# Speed: 0.5ms preprocess, 1.7ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_imgsz_480\test_split_metrics
#   ... took 44.5 sec
# pickling results to: 'runs_puhti\long_runs\150ep_imgsz_480\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_imgsz_480\test_split_metrics\images
#   [10/30] VALIDATING: "runs_puhti/long_runs/150ep_lr0_half"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 565.2743.9 MB/s, size: 198.5 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.8it/s 27.2s<0.1ss
#                    all       3840       5416      0.641      0.523      0.568      0.294
#                    D00       1339       2615       0.64      0.529      0.566      0.317
#                    D10        743       1087      0.614      0.532      0.567      0.279
#                    D20        873       1086      0.687      0.634      0.665      0.361
#                    D40        357        628      0.622      0.398      0.473      0.218
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_lr0_half\test_split_metrics
#   ... took 49.8 sec
# pickling results to: 'runs_puhti\long_runs\150ep_lr0_half\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_lr0_half\test_split_metrics\images
#   [11/30] VALIDATING: "runs_puhti/long_runs/150ep_no_drone"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 794.6799.7 MB/s, size: 513.3 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.5it/s 28.3s<0.1ss
#                    all       3840       5416      0.702      0.572      0.643       0.36
#                    D00       1339       2615      0.685      0.555      0.614      0.369
#                    D10        743       1087      0.653      0.546      0.601      0.308
#                    D20        873       1086      0.771      0.704      0.771      0.476
#                    D40        357        628      0.697      0.484      0.587      0.288
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_no_drone\test_split_metrics
#   ... took 51.4 sec
# pickling results to: 'runs_puhti\long_runs\150ep_no_drone\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_no_drone\test_split_metrics\images
#   [12/30] VALIDATING: "runs_puhti/long_runs/150ep_normal"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 197.298.1 MB/s, size: 55.9 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.6it/s 28.0s<0.1ss
#                    all       3840       5416      0.641      0.523      0.568      0.294
#                    D00       1339       2615       0.64      0.529      0.566      0.317
#                    D10        743       1087      0.614      0.532      0.567      0.279
#                    D20        873       1086      0.687      0.634      0.665      0.361
#                    D40        357        628      0.622      0.398      0.473      0.218
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_normal\test_split_metrics
#   ... took 50.8 sec
# pickling results to: 'runs_puhti\long_runs\150ep_normal\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_normal\test_split_metrics\images
#   [13/30] VALIDATING: "runs_puhti/long_runs/150ep_scale_trans_off"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 629.0887.7 MB/s, size: 366.5 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.9it/s 27.0s0.2sss
#                    all       3840       5416      0.621      0.527      0.568      0.294
#                    D00       1339       2615      0.621      0.514      0.561      0.311
#                    D10        743       1087        0.6      0.534      0.566      0.286
#                    D20        873       1086      0.665      0.631      0.662      0.365
#                    D40        357        628      0.598      0.428      0.482      0.215
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\150ep_scale_trans_off\test_split_metrics
#   ... took 49.8 sec
# pickling results to: 'runs_puhti\long_runs\150ep_scale_trans_off\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\150ep_scale_trans_off\test_split_metrics\images
#   [14/30] VALIDATING: "runs_puhti/long_runs/180ep_degrees"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 577.8811.9 MB/s, size: 213.7 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.8it/s 27.3ss<0.1s
#                    all       3840       5416      0.624      0.505      0.553      0.268
#                    D00       1339       2615      0.615      0.508      0.553      0.291
#                    D10        743       1087      0.574      0.495      0.521      0.232
#                    D20        873       1086      0.689        0.6      0.657      0.335
#                    D40        357        628      0.617      0.417      0.479      0.214
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\180ep_degrees\test_split_metrics
#   ... took 51.3 sec
# pickling results to: 'runs_puhti\long_runs\180ep_degrees\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\180ep_degrees\test_split_metrics\images
#   [15/30] VALIDATING: "runs_puhti/long_runs/180ep_normal"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 543.4715.5 MB/s, size: 212.6 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.2it/s 29.1s<0.1ss
#                    all       3840       5416      0.624      0.533      0.572      0.296
#                    D00       1339       2615       0.61      0.533      0.563      0.314
#                    D10        743       1087      0.594      0.552      0.571      0.284
#                    D20        873       1086       0.67      0.642      0.671      0.367
#                    D40        357        628      0.623      0.406      0.481      0.219
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\180ep_normal\test_split_metrics
#   ... took 53.3 sec
# pickling results to: 'runs_puhti\long_runs\180ep_normal\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\180ep_normal\test_split_metrics\images
#   [16/30] VALIDATING: "runs_puhti/long_runs/1st_150ep"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 261.637.9 MB/s, size: 82.9 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.4it/s 28.6s<0.1ss
#                    all       3840       5416      0.706       0.61      0.689      0.396
#                    D00       1339       2615        0.7      0.608      0.666      0.404
#                    D10        743       1087      0.684      0.592      0.672      0.358
#                    D20        873       1086      0.765      0.735       0.81      0.519
#                    D40        357        628      0.677      0.505      0.608      0.302
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\1st_150ep\test_split_metrics
#   ... took 51.6 sec
# pickling results to: 'runs_puhti\long_runs\1st_150ep\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\1st_150ep\test_split_metrics\images
#   [17/30] VALIDATING: "runs_puhti/long_runs/250ep"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 543.0792.0 MB/s, size: 211.4 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.8it/s 27.2s<0.1ss
#                    all       3840       5416      0.701      0.627      0.689      0.396
#                    D00       1339       2615      0.696      0.609      0.665      0.405
#                    D10        743       1087      0.669       0.61      0.669      0.359
#                    D20        873       1086      0.758      0.753      0.821      0.524
#                    D40        357        628       0.68      0.538      0.603      0.298
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\250ep\test_split_metrics
#   ... took 50.1 sec
# pickling results to: 'runs_puhti\long_runs\250ep\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\250ep\test_split_metrics\images
#   [18/30] VALIDATING: "runs_puhti/long_runs/90ep"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 905.5884.0 MB/s, size: 413.6 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.7it/s 27.6s<0.1ss
#                    all       3840       5416      0.668      0.576      0.635      0.351
#                    D00       1339       2615      0.655      0.572      0.616      0.363
#                    D10        743       1087      0.638      0.565      0.623      0.327
#                    D20        873       1086      0.738      0.689      0.759      0.452
#                    D40        357        628      0.639      0.478      0.541      0.263
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\long_runs\90ep\test_split_metrics
#   ... took 50.8 sec
# pickling results to: 'runs_puhti\long_runs\90ep\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\long_runs\90ep\test_split_metrics\images
#   [19/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_RMSProp"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.1 ms, read: 236.776.2 MB/s, size: 71.5 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.7it/s 27.6s<0.1ss
#                    all       3840       5416   0.000334     0.0983   0.000695   0.000158
#                    D00       1339       2615    2.1e-05   0.000765   1.09e-05   1.62e-06
#                    D10        743       1087          0          0          0          0
#                    D20        873       1086    0.00131      0.392    0.00277   0.000629
#                    D40        357        628          0          0          0          0
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_RMSProp\test_split_metrics
#   ... took 50.8 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_RMSProp\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_RMSProp\test_split_metrics\images
#   [20/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_SGD"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 1130.4935.2 MB/s, size: 823.4 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.3it/s 28.8s<0.1ss
#                    all       3840       5416      0.642      0.507      0.564      0.293
#                    D00       1339       2615      0.644      0.515      0.557      0.313
#                    D10        743       1087      0.625      0.523      0.566      0.281
#                    D20        873       1086      0.687      0.616      0.664      0.367
#                    D40        357        628      0.612      0.373      0.467      0.211
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_SGD\test_split_metrics
#   ... took 51.2 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_SGD\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_SGD\test_split_metrics\images
#   [21/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_SGD_lr0"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 253.1102.8 MB/s, size: 72.1 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.4it/s 28.5s<0.1ss
#                    all       3840       5416      0.632      0.528       0.57      0.295
#                    D00       1339       2615      0.625      0.517      0.555      0.308
#                    D10        743       1087      0.618      0.535      0.569      0.275
#                    D20        873       1086      0.684      0.634      0.673      0.373
#                    D40        357        628        0.6      0.427      0.481      0.222
# Speed: 0.7ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_SGD_lr0\test_split_metrics
#   ... took 61.1 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_SGD_lr0\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_SGD_lr0\test_split_metrics\images
#   [22/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_SGD_lr0_lower"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 172.493.8 MB/s, size: 224.1 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.0it/s 30.2s<0.1s
#                    all       3840       5416      0.624      0.532      0.573      0.294
#                    D00       1339       2615      0.635      0.522      0.559      0.309
#                    D10        743       1087      0.593      0.535      0.559      0.275
#                    D20        873       1086      0.688      0.639      0.677      0.369
#                    D40        357        628      0.579      0.435      0.499      0.222
# Speed: 1.2ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_SGD_lr0_lower\test_split_metrics
#   ... took 57.4 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_SGD_lr0_lower\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_SGD_lr0_lower\test_split_metrics\images
#   [23/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_SGD_mom_higher"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 398.5446.7 MB/s, size: 229.5 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.4it/s 28.5s<0.1ss
#                    all       3840       5416      0.639      0.525      0.572      0.296
#                    D00       1339       2615      0.624       0.53      0.565      0.318
#                    D10        743       1087       0.62      0.528      0.576      0.288
#                    D20        873       1086      0.681       0.64      0.675      0.365
#                    D40        357        628      0.632      0.404      0.474      0.214
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_SGD_mom_higher\test_split_metrics
#   ... took 50.4 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_SGD_mom_higher\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_SGD_mom_higher\test_split_metrics\images
#   [24/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_SGD_mom_lower"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 556.0718.5 MB/s, size: 353.9 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.9it/s 27.1s<0.2ss
#                    all       3840       5416      0.647      0.534      0.576      0.294
#                    D00       1339       2615      0.643      0.527      0.565      0.316
#                    D10        743       1087      0.623      0.527      0.566      0.279
#                    D20        873       1086      0.695      0.642      0.679      0.364
#                    D40        357        628      0.628      0.441      0.494      0.216
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_SGD_mom_lower\test_split_metrics
#   ... took 50.2 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_SGD_mom_lower\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_SGD_mom_lower\test_split_metrics\images
#   [25/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_adamX"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 587.9784.0 MB/s, size: 205.3 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.6it/s 28.0s<0.1ss
#                    all       3840       5416      0.599      0.477      0.519      0.263
#                    D00       1339       2615      0.597      0.494      0.525      0.289
#                    D10        743       1087      0.578      0.477      0.506      0.243
#                    D20        873       1086      0.641      0.573      0.619      0.332
#                    D40        357        628      0.579      0.366      0.427      0.187
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_adamX\test_split_metrics
#   ... took 50.2 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_adamX\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_adamX\test_split_metrics\images
#   [26/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_adam"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 1161.4844.7 MB/s, size: 593.9 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.5it/s 28.2s<0.1ss
#                    all       3840       5416      0.498      0.381      0.391      0.186
#                    D00       1339       2615      0.476      0.439      0.423      0.214
#                    D10        743       1087      0.465       0.38       0.37      0.159
#                    D20        873       1086      0.508      0.474      0.482      0.249
#                    D40        357        628      0.541      0.229      0.289      0.122
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_adam\test_split_metrics
#   ... took 50.8 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_adam\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_adam\test_split_metrics\images
#   [27/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_adamw"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 676.1884.1 MB/s, size: 465.5 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.3it/s 28.8s<0.1ss
#                    all       3840       5416      0.594      0.527      0.553      0.281
#                    D00       1339       2615      0.596      0.534      0.544      0.298
#                    D10        743       1087      0.549      0.534      0.541      0.263
#                    D20        873       1086      0.651      0.643      0.662      0.355
#                    D40        357        628      0.579      0.396      0.467      0.207
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_adamw\test_split_metrics
#   ... took 53.6 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_adamw\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_adamw\test_split_metrics\images
#   [28/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_adamw_lr0"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 227.655.6 MB/s, size: 67.4 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.4it/s 28.6s<0.1ss
#                    all       3840       5416      0.625      0.507      0.557      0.281
#                    D00       1339       2615      0.631      0.506      0.545      0.297
#                    D10        743       1087      0.589       0.52      0.557      0.275
#                    D20        873       1086       0.66      0.613      0.651      0.347
#                    D40        357        628      0.621      0.389      0.474      0.205
# Speed: 0.8ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_adamw_lr0\test_split_metrics
#   ... took 55.1 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_adamw_lr0\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_adamw_lr0\test_split_metrics\images
#   [29/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_nadam"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 354.1365.7 MB/s, size: 435.2 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.4it/s 28.7s<0.1ss
#                    all       3840       5416       0.52      0.394      0.413      0.198
#                    D00       1339       2615        0.5      0.441      0.442      0.226
#                    D10        743       1087      0.513      0.404      0.394      0.173
#                    D20        873       1086      0.556      0.493      0.501      0.262
#                    D40        357        628      0.512      0.239      0.314      0.131
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_nadam\test_split_metrics
#   ... took 52.6 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_nadam\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_nadam\test_split_metrics\images
#   [30/30] VALIDATING: "runs_puhti/optimizers/opt_150ep_radam"
# Ultralytics 8.3.253  Python-3.12.11 torch-2.10.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 413.3649.6 MB/s, size: 258.9 KB)
# val: Scanning A:\datasets\kandi\test_PP_Matti\labels\test.cache... 3840 images, 1455 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 8.7it/s 27.7s<0.1ss
#                    all       3840       5416      0.503      0.392      0.406      0.196
#                    D00       1339       2615      0.485       0.44      0.435      0.227
#                    D10        743       1087      0.482      0.412      0.386      0.173
#                    D20        873       1086      0.521      0.483       0.49      0.253
#                    D40        357        628      0.525      0.234      0.314       0.13
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\stirl\MyDocuments\Code\_Projects\Kandi2025\Kandi2025-repo\ultralytics\runs\detect\runs_puhti\optimizers\opt_150ep_radam\test_split_metrics
#   ... took 50.3 sec
# pickling results to: 'runs_puhti\optimizers\opt_150ep_radam\test_split_metrics\metrics.pkl'
# moving images dir to: runs_puhti\optimizers\opt_150ep_radam\test_split_metrics\images

# %% [markdown]
# ### STEP 2: Metrics processing

# %%
# Read pickled metrics, build dataframe of metrics and save to csv
col_names = "Class mAP50 mAP50-95 Box-P Box-R Box-F1".split()
class_names = "mean D00 D10 D20 D40".split()

# construct data dict
new_col_names = [
    f"{col}_{cls}"
    for col in col_names if col != "Class"
    for cls in class_names
]
data: dict[str, list[pl.Float64]] = { k: [] for k in new_col_names }

# iterate
for run_path in run_paths:
    metrics_pkl_path = run_path / TEST_METRICS_FOLDER / "metrics.pkl"
    metrics_pkl_path.exists()
    results: metrics.DetMetrics
    with open(metrics_pkl_path, 'rb') as f:
        results = pickle.load(f)

    # get results df
    df = results.to_df()
    df = df[col_names]

    # compute mean row
    mean_row = (
        df
        .select(pl.exclude("Class").mean())
        .with_columns(pl.lit("mean").alias("Class"))
        .select(df.columns)   # reorder
    )
    df = pl.concat([df, mean_row], how="vertical")

    # add values to data{}
    for cls in class_names:
        cls_d = df.filter(pl.col("Class") == cls).to_dict(as_series=False)
        del cls_d["Class"]
        for k, v in cls_d.items():
            key = f"{k}_{cls}"
            data[key] = data.get(key, []) + v

# create new df and save csv
run_paths_short =  [ str(p).replace("runs_puhti\\", "").split('\\') for p in run_paths ]
run_names =  [ p[1] for p in run_paths_short ]
run_groups = [ p[0] for p in run_paths_short ]
d = { "run_name": run_names, "run_group": run_groups } | data # add run_name as col
df_all = pl.DataFrame(d)
df_all.write_csv("analytics/test_set_metrics_table.csv")
df_all
# Out:
# shape: (30, 27)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ run_name  ┆ run_group ┆ mAP50_mea ┆ mAP50_D00 ┆ … ┆ Box-F1_D0 ┆ Box-F1_D1 ┆ Box-F1_D2 ┆ Box-F1_D │
# │ ---       ┆ ---       ┆ n         ┆ ---       ┆   ┆ 0         ┆ 0         ┆ 0         ┆ 40       │
# │ str       ┆ str       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ f64       ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 150ep_bch ┆ long_runs ┆ 0.57453   ┆ 0.56949   ┆ … ┆ 0.58124   ┆ 0.5632    ┆ 0.65452   ┆ 0.48644  │
# │ _32       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 150ep_bch ┆ long_runs ┆ 0.558535  ┆ 0.55044   ┆ … ┆ 0.56425   ┆ 0.55083   ┆ 0.65043   ┆ 0.48028  │
# │ _8        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 150ep_cro ┆ long_runs ┆ 0.5679375 ┆ 0.56615   ┆ … ┆ 0.5792    ┆ 0.57018   ┆ 0.65929   ┆ 0.48543  │
# │ p         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 150ep_deg ┆ long_runs ┆ 0.54259   ┆ 0.55062   ┆ … ┆ 0.55767   ┆ 0.52653   ┆ 0.63214   ┆ 0.47932  │
# │ rees      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 150ep_fli ┆ long_runs ┆ 0.565455  ┆ 0.5622    ┆ … ┆ 0.56295   ┆ 0.56156   ┆ 0.65726   ┆ 0.4691   │
# │ pup       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ opt_150ep ┆ optimizer ┆ 0.391022  ┆ 0.42305   ┆ … ┆ 0.45654   ┆ 0.41826   ┆ 0.49057   ┆ 0.32214  │
# │ _adam     ┆ s         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ opt_150ep ┆ optimizer ┆ 0.55341   ┆ 0.54397   ┆ … ┆ 0.56339   ┆ 0.54177   ┆ 0.64685   ┆ 0.47053  │
# │ _adamw    ┆ s         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ opt_150ep ┆ optimizer ┆ 0.556735  ┆ 0.54471   ┆ … ┆ 0.56146   ┆ 0.5522    ┆ 0.63583   ┆ 0.47791  │
# │ _adamw_lr ┆ s         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ opt_150ep ┆ optimizer ┆ 0.41262   ┆ 0.44183   ┆ … ┆ 0.46846   ┆ 0.45204   ┆ 0.52258   ┆ 0.32582  │
# │ _nadam    ┆ s         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ opt_150ep ┆ optimizer ┆ 0.4061975 ┆ 0.43542   ┆ … ┆ 0.46129   ┆ 0.44442   ┆ 0.50152   ┆ 0.32383  │
# │ _radam    ┆ s         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
