# %% [markdown]
# # Computing and Saving Test Metrics for Trained Models

# %%
# NOTE: run only once!
import os
os.chdir('..')

# %%
from pathlib import Path
import time
import pickle
import shutil
import polars as pl

from ultralytics import YOLO # type: ignore
from ultralytics import settings
from ultralytics.utils import metrics

# %%
PURPLE = "\033[0;35m"
END = "\033[0m"

# %%
# YOLO setup

# Set datasets (root) directory path
DATASETS_DIR = "datasets"
RUNS_DIR = "./ultralytics/runs"
WEIGHTS_DIR = "./ultralytics/weights"

if not Path(DATASETS_DIR).exists():
    raise FileNotFoundError(f"Please set path to existing folder. Current doesn't exist: '{DATASETS_DIR}'")

# Set yaml file
YAML_FILE = "./YAML/RDD2022_kaikki.yaml"
if not Path(YAML_FILE).exists():
    raise FileNotFoundError(f"Please set path to existing YAML file. Current doesn't exist: '{YAML_FILE}'")

# YOLO settings
settings.reset() # resets YOLO settings
settings.update({
    "datasets_dir": DATASETS_DIR,
    "runs_dir":     RUNS_DIR,
    "weights_dir":  WEIGHTS_DIR,
})
# settings

# %%
# Get model paths
filters = [
    # 'long_runs',
    # '150ep',
    # 'normal',
]

# choose which model formats to test
model_names = ['best.pt', 'best_full_integer_quant.tflite']
base_dir = 'runs_puhti'  # base folder for model directories


run_paths = []
for name in model_names:
    run_paths.extend(Path(base_dir).rglob(name))

run_paths = sorted(
    run_paths,
    key=lambda obj: str(obj),
)

run_paths = [ p.parent.parent for p in run_paths ]
for f in filters:
    run_paths = [ p for p in run_paths if f in str(p) ]
# Out:
# [PosixPath('runs_puhti/long_runs/150ep_bch_32.quant.320'), PosixPath('runs_puhti/long_runs/150ep_bch_32.quant.640'), PosixPath('runs_puhti/long_runs/150ep_bch_32'), PosixPath('runs_puhti/long_runs/150ep_bch_8.quant.320'), PosixPath('runs_puhti/long_runs/150ep_bch_8.quant.640'), PosixPath('runs_puhti/long_runs/150ep_bch_8'), PosixPath('runs_puhti/long_runs/150ep_crop.quant.320'), PosixPath('runs_puhti/long_runs/150ep_crop.quant.640'), PosixPath('runs_puhti/long_runs/150ep_crop'), PosixPath('runs_puhti/long_runs/150ep_degrees.quant.320'), PosixPath('runs_puhti/long_runs/150ep_degrees.quant.640'), PosixPath('runs_puhti/long_runs/150ep_degrees'), PosixPath('runs_puhti/long_runs/150ep_flipup.quant.320'), PosixPath('runs_puhti/long_runs/150ep_flipup.quant.640'), PosixPath('runs_puhti/long_runs/150ep_flipup'), PosixPath('runs_puhti/long_runs/150ep_hsv.quant.320'), PosixPath('runs_puhti/long_runs/150ep_hsv.quant.640'), PosixPath('runs_puhti/long_runs/150ep_hsv'), PosixPath('runs_puhti/long_runs/150ep_imgsz_320.quant.320'), PosixPath('runs_puhti/long_runs/150ep_imgsz_320.quant.640'), PosixPath('runs_puhti/long_runs/150ep_imgsz_320'), PosixPath('runs_puhti/long_runs/150ep_imgsz_400.quant.320'), PosixPath('runs_puhti/long_runs/150ep_imgsz_400.quant.640'), PosixPath('runs_puhti/long_runs/150ep_imgsz_400'), PosixPath('runs_puhti/long_runs/150ep_imgsz_480.quant.320'), PosixPath('runs_puhti/long_runs/150ep_imgsz_480.quant.640'), PosixPath('runs_puhti/long_runs/150ep_imgsz_480'), PosixPath('runs_puhti/long_runs/150ep_lr0_half.quant.320'), PosixPath('runs_puhti/long_runs/150ep_lr0_half.quant.640'), PosixPath('runs_puhti/long_runs/150ep_lr0_half'), PosixPath('runs_puhti/long_runs/150ep_no_drone.quant.320'), PosixPath('runs_puhti/long_runs/150ep_no_drone.quant.640'), PosixPath('runs_puhti/long_runs/150ep_no_drone'), PosixPath('runs_puhti/long_runs/150ep_normal.quant.320'), PosixPath('runs_puhti/long_runs/150ep_normal.quant.640'), PosixPath('runs_puhti/long_runs/150ep_normal'), PosixPath('runs_puhti/long_runs/150ep_scale_trans_off.quant.320'), PosixPath('runs_puhti/long_runs/150ep_scale_trans_off.quant.640'), PosixPath('runs_puhti/long_runs/150ep_scale_trans_off'), PosixPath('runs_puhti/long_runs/180ep_degrees.quant.320'), PosixPath('runs_puhti/long_runs/180ep_degrees.quant.640'), PosixPath('runs_puhti/long_runs/180ep_degrees'), PosixPath('runs_puhti/long_runs/180ep_normal.quant.320'), PosixPath('runs_puhti/long_runs/180ep_normal.quant.640'), PosixPath('runs_puhti/long_runs/180ep_normal'), PosixPath('runs_puhti/long_runs/1st_150ep.quant.320'), PosixPath('runs_puhti/long_runs/1st_150ep.quant.640'), PosixPath('runs_puhti/long_runs/1st_150ep'), PosixPath('runs_puhti/long_runs/250ep.quant.320'), PosixPath('runs_puhti/long_runs/250ep.quant.640'), PosixPath('runs_puhti/long_runs/250ep'), PosixPath('runs_puhti/long_runs/90ep.quant.320'), PosixPath('runs_puhti/long_runs/90ep.quant.640'), PosixPath('runs_puhti/long_runs/90ep'), PosixPath('runs_puhti/optimizers/opt_150ep_RMSProp.quant.320'), PosixPath('runs_puhti/optimizers/opt_150ep_RMSProp.quant.640'), PosixPath('runs_puhti/optimizers/opt_150ep_RMSProp'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD.quant.320'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD.quant.640'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_lr0.quant.320'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_lr0.quant.640'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_lr0'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_lr0_lower.quant.320'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_lr0_lower.quant.640'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_lr0_lower'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_mom_higher.quant.320'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_mom_higher.quant.640'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_mom_higher'), PosixPath('runs_puhti/optimizers/opt_150ep_SGD_mom_lower.quant.320'), PosixPath('runs_puhti/optimizers/opt_150 ...

# %% [markdown]
# ### STEP 1: compute metrics

# %%
test_image_sizes = [640, 320]

run_count = ( len([p for p in run_paths if p.name.find(".") == -1 ])*len(test_image_sizes)  # runs count for non-quantized models
             + len([p for p in run_paths if p.name.find(".") > -1 ]))  # run count for quantized models

print(f"Running up to {run_count} model tests, this may take a while...")

# RUN: Compute metrics for test set
TEST_METRICS_FOLDER_base = "test_split_metrics"
# save metrics file name format "TEST_METRICS_FOLDER_base.quant/original.640/320"

REDO = True
for imgsz in test_image_sizes:
    for i, run_path in enumerate(run_paths):
        print(f"Testing model: {run_path} | Test image size: {imgsz}")
        
        # check for image size mismatch, quantized models can only run inference at their export imgsz
        if run_path.name.count(".") > 0 and not run_path.name.endswith(f".{imgsz}"):
            # print(f"\nSkipping model.val() for {run_path.name} with imgsz={imgsz} due to image size mismatch.\n")
            continue
        
        if Path(run_path / "weights/best.pt").exists():
            model_path = run_path / "weights/best.pt"
            
            # modify results foder name
            TEST_METRICS_FOLDER = ".".join([TEST_METRICS_FOLDER_base, "original", str(imgsz)])
            
        elif Path(run_path / "best_saved_model/best_full_integer_quant.tflite").exists():
            model_path = run_path / "best_saved_model/best_full_integer_quant.tflite"
            
            # modify results foder name
            TEST_METRICS_FOLDER = ".".join([TEST_METRICS_FOLDER_base, "quant", str(imgsz)])
        else:
            raise FileNotFoundError(f"No model found in {run_path}")
        
        name = str(run_path).replace("\\", "/")
        print(f"  [{i+1:>2}/{run_count}] VALIDATING: \"{PURPLE}{name}{END}\"")
        
        # paths and check
        results_dir = run_path / TEST_METRICS_FOLDER
        results_pkl = results_dir / "metrics.pkl"
        if results_pkl.exists() and not REDO:
            print('  ... skipping')
            continue
        
        # validate
        start = time.time()
        model = YOLO(model_path)
        
        results: metrics.DetMetrics = model.val(
            data = YAML_FILE,
            split = "test",
            task = "detect",
            project = run_path,
            name = TEST_METRICS_FOLDER,
            imgsz = imgsz
        )
            
        print("  ... took {:.1f} sec".format(time.time()-start))
    
        # save pickle
        results_pkl.parent.mkdir(exist_ok=True)
        print(f"pickling results to: '{results_pkl}'")
        with open(results_pkl, "wb") as f:
            pickle.dump(results, f)
        
        # move saved images to desired dir
        matches = list(Path(RUNS_DIR).rglob(f"*{run_path}/{TEST_METRICS_FOLDER}"))
        if len(matches) == 0:
            raise FileExistsError(f"cant find images generated by .val().")
        images_path = matches[0]
        new_images_path = Path("./") / images_path.relative_to(f"{RUNS_DIR}/detect") / "images"
        print('moving images dir to:', new_images_path)
        if not new_images_path.exists():
            shutil.move(images_path, new_images_path)
# Out:
# Running up to 2 (image sizes) x 90 (models) = 180 model tests, this may take a while...
# Testing model: runs_puhti/long_runs/150ep_bch_32.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_bch_32.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_bch_32.quant.640 | Test image size: 640
#   [ 2/90] VALIDATING: "runs_puhti/long_runs/150ep_bch_32.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_bch_32.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2257.4±1118.8 MB/s, size: 272.3 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.0Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.3it/s 5:11<0.1s
#                    all       3840       5430      0.532      0.385      0.392      0.192
#                    D00       1349       2626      0.519       0.41      0.416       0.21
#                    D10        744       1090       0.47       0.45      0.414      0.191
#                    D20        873       1086      0.668      0.425      0.472      0.243
#                    D40        357        628      0.473      0.256      0.265      0.124
# Speed: 1.0ms preprocess, 71.0ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_bch_32.quant.640/test_split_metrics.quant.640
#   ... took 314.9 sec
# pickling results to: 'runs_puhti/long_runs/150ep_bch_32.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_bch_32.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_bch_32 | Test image size: 640
#   [ 3/90] VALIDATING: "runs_puhti/long_runs/150ep_bch_32"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4826.8±2245.3 MB/s, size: 352.3 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 519.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 5.8it/s 41.2s<0.2s
#                    all       3840       5430      0.644      0.516      0.574      0.299
#                    D00       1349       2626      0.658      0.519      0.569      0.318
#                    D10        744       1090      0.625      0.511      0.561      0.283
#                    D20        873       1086       0.69      0.624      0.672      0.366
#                    D40        357        628      0.603      0.408      0.495      0.228
# Speed: 0.7ms preprocess, 8.6ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_bch_32/test_split_metrics.original.640
#   ... took 44.0 sec
# pickling results to: 'runs_puhti/long_runs/150ep_bch_32/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_bch_32/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_bch_8.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_bch_8.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_bch_8.quant.640 | Test image size: 640
#   [ 5/90] VALIDATING: "runs_puhti/long_runs/150ep_bch_8.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_bch_8.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4877.8±2048.3 MB/s, size: 417.3 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.1Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.3it/s 5:13<0.1s
#                    all       3840       5430      0.517      0.418      0.419      0.204
#                    D00       1349       2626      0.491      0.434      0.422      0.213
#                    D10        744       1090      0.475      0.469      0.425       0.19
#                    D20        873       1086      0.611      0.494      0.536      0.282
#                    D40        357        628       0.49      0.275      0.296      0.129
# Speed: 1.0ms preprocess, 71.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_bch_8.quant.640/test_split_metrics.quant.640
#   ... took 314.6 sec
# pickling results to: 'runs_puhti/long_runs/150ep_bch_8.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_bch_8.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_bch_8 | Test image size: 640
#   [ 6/90] VALIDATING: "runs_puhti/long_runs/150ep_bch_8"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4627.8±2093.0 MB/s, size: 311.0 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 5.5it/s 43.7s<0.2s
#                    all       3840       5430       0.62      0.514      0.558      0.291
#                    D00       1349       2626      0.619      0.518       0.55      0.305
#                    D10        744       1090      0.588      0.517      0.546      0.269
#                    D20        873       1086      0.691      0.615      0.669      0.371
#                    D40        357        628      0.584      0.408      0.469      0.219
# Speed: 0.7ms preprocess, 8.9ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_bch_8/test_split_metrics.original.640
#   ... took 46.4 sec
# pickling results to: 'runs_puhti/long_runs/150ep_bch_8/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_bch_8/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_crop.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_crop.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_crop.quant.640 | Test image size: 640
#   [ 8/90] VALIDATING: "runs_puhti/long_runs/150ep_crop.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_crop.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3982.3±1846.0 MB/s, size: 195.7 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 947.4Mit/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.7it/s 5:02<0.2s
#                    all       3840       5430      0.565      0.437      0.448      0.214
#                    D00       1349       2626      0.569      0.421       0.45       0.23
#                    D10        744       1090      0.517      0.468      0.439        0.2
#                    D20        873       1086      0.653      0.526      0.553      0.278
#                    D40        357        628      0.521      0.334      0.347       0.15
# Speed: 0.7ms preprocess, 71.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_crop.quant.640/test_split_metrics.quant.640
#   ... took 303.9 sec
# pickling results to: 'runs_puhti/long_runs/150ep_crop.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_crop.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_crop | Test image size: 640
#   [ 9/90] VALIDATING: "runs_puhti/long_runs/150ep_crop"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4393.4±1748.9 MB/s, size: 473.7 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.4it/s 37.3s<0.2s
#                    all       3840       5430      0.641      0.522      0.568      0.294
#                    D00       1349       2626      0.641      0.527      0.566      0.318
#                    D10        744       1090      0.614      0.531      0.565      0.279
#                    D20        873       1086      0.687      0.634      0.665      0.362
#                    D40        357        628      0.622      0.398      0.474      0.218
# Speed: 0.6ms preprocess, 7.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_crop/test_split_metrics.original.640
#   ... took 39.7 sec
# pickling results to: 'runs_puhti/long_runs/150ep_crop/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_crop/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_degrees.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_degrees.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_degrees.quant.640 | Test image size: 640
#   [11/90] VALIDATING: "runs_puhti/long_runs/150ep_degrees.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_degrees.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2441.9±888.3 MB/s, size: 71.5 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.7it/s 5:01<0.1s
#                    all       3840       5430      0.463      0.331      0.321      0.128
#                    D00       1349       2626      0.442      0.375      0.347      0.146
#                    D10        744       1090      0.357      0.352      0.282     0.0824
#                    D20        873       1086      0.616      0.365      0.421      0.198
#                    D40        357        628      0.438      0.231      0.232     0.0853
# Speed: 0.6ms preprocess, 71.0ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_degrees.quant.640/test_split_metrics.quant.640
#   ... took 302.6 sec
# pickling results to: 'runs_puhti/long_runs/150ep_degrees.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_degrees.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_degrees | Test image size: 640
#   [12/90] VALIDATING: "runs_puhti/long_runs/150ep_degrees"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5010.5±1763.4 MB/s, size: 282.2 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.3it/s 37.8s<0.2s
#                    all       3840       5430      0.613        0.5      0.543      0.265
#                    D00       1349       2626      0.612      0.513      0.551      0.289
#                    D10        744       1090      0.566      0.491        0.5       0.22
#                    D20        873       1086      0.679      0.591      0.654      0.342
#                    D40        357        628      0.597      0.403      0.468       0.21
# Speed: 0.6ms preprocess, 7.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_degrees/test_split_metrics.original.640
#   ... took 40.2 sec
# pickling results to: 'runs_puhti/long_runs/150ep_degrees/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_degrees/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_flipup.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_flipup.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_flipup.quant.640 | Test image size: 640
#   [14/90] VALIDATING: "runs_puhti/long_runs/150ep_flipup.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_flipup.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3205.8±1006.1 MB/s, size: 75.9 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.8it/s 5:01<0.2s
#                    all       3840       5430      0.559      0.411      0.435      0.212
#                    D00       1349       2626      0.537      0.437      0.446      0.228
#                    D10        744       1090      0.516      0.453      0.452      0.211
#                    D20        873       1086      0.637      0.474       0.53      0.271
#                    D40        357        628      0.544       0.28      0.312      0.139
# Speed: 0.6ms preprocess, 71.0ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_flipup.quant.640/test_split_metrics.quant.640
#   ... took 302.5 sec
# pickling results to: 'runs_puhti/long_runs/150ep_flipup.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_flipup.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_flipup | Test image size: 640
#   [15/90] VALIDATING: "runs_puhti/long_runs/150ep_flipup"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4739.5±2100.7 MB/s, size: 451.4 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.5Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.4it/s 37.4s<0.2s
#                    all       3840       5430      0.631      0.511      0.566      0.293
#                    D00       1349       2626       0.63      0.509      0.562      0.315
#                    D10        744       1090       0.61      0.519      0.571      0.286
#                    D20        873       1086      0.693      0.627      0.671      0.366
#                    D40        357        628      0.592      0.389      0.459      0.206
# Speed: 0.6ms preprocess, 7.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_flipup/test_split_metrics.original.640
#   ... took 39.7 sec
# pickling results to: 'runs_puhti/long_runs/150ep_flipup/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_flipup/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_hsv.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_hsv.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_hsv.quant.640 | Test image size: 640
#   [17/90] VALIDATING: "runs_puhti/long_runs/150ep_hsv.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_hsv.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3292.4±1528.7 MB/s, size: 210.6 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.8it/s 5:00<0.1s
#                    all       3840       5430      0.585       0.41      0.442      0.213
#                    D00       1349       2626      0.585      0.418      0.451      0.226
#                    D10        744       1090      0.565       0.41      0.432      0.198
#                    D20        873       1086      0.661      0.501      0.553      0.284
#                    D40        357        628      0.527      0.311      0.333      0.145
# Speed: 0.6ms preprocess, 70.9ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_hsv.quant.640/test_split_metrics.quant.640
#   ... took 301.7 sec
# pickling results to: 'runs_puhti/long_runs/150ep_hsv.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_hsv.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_hsv | Test image size: 640
#   [18/90] VALIDATING: "runs_puhti/long_runs/150ep_hsv"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4684.1±2094.5 MB/s, size: 213.8 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.5it/s 36.8s<0.2s
#                    all       3840       5430      0.646      0.521      0.569      0.293
#                    D00       1349       2626      0.636      0.524      0.563      0.313
#                    D10        744       1090      0.623       0.52      0.564       0.28
#                    D20        873       1086      0.688      0.633      0.674      0.366
#                    D40        357        628      0.638      0.408      0.474      0.215
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_hsv/test_split_metrics.original.640
#   ... took 39.4 sec
# pickling results to: 'runs_puhti/long_runs/150ep_hsv/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_hsv/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_imgsz_320.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_imgsz_320.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_imgsz_320.quant.640 | Test image size: 640
#   [20/90] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_320.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_imgsz_320.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3403.6±1818.2 MB/s, size: 426.6 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.0Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.7it/s 5:01<0.1s
#                    all       3840       5430       0.42      0.278      0.254      0.102
#                    D00       1349       2626      0.454      0.297      0.283      0.126
#                    D10        744       1090      0.354      0.281      0.221     0.0799
#                    D20        873       1086      0.484      0.356      0.336      0.131
#                    D40        357        628      0.388      0.178      0.176     0.0693
# Speed: 0.6ms preprocess, 71.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_imgsz_320.quant.640/test_split_metrics.quant.640
#   ... took 302.7 sec
# pickling results to: 'runs_puhti/long_runs/150ep_imgsz_320.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_imgsz_320.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_imgsz_320 | Test image size: 640
#   [21/90] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_320"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5270.6±3155.9 MB/s, size: 334.3 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.5it/s 37.0s<0.2s
#                    all       3840       5430      0.452      0.405      0.366      0.154
#                    D00       1349       2626      0.483      0.403      0.373      0.176
#                    D10        744       1090      0.375      0.378      0.297      0.119
#                    D20        873       1086      0.492      0.531      0.486        0.2
#                    D40        357        628       0.46      0.306       0.31      0.119
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_imgsz_320/test_split_metrics.original.640
#   ... took 39.3 sec
# pickling results to: 'runs_puhti/long_runs/150ep_imgsz_320/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_imgsz_320/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_imgsz_400.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_imgsz_400.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_imgsz_400.quant.640 | Test image size: 640
#   [23/90] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_400.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_imgsz_400.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3396.6±1622.7 MB/s, size: 399.5 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.8it/s 5:00<0.1s
#                    all       3840       5430      0.507      0.332      0.342       0.15
#                    D00       1349       2626      0.538      0.357      0.381      0.178
#                    D10        744       1090      0.452      0.339      0.327      0.137
#                    D20        873       1086      0.564      0.387      0.412      0.178
#                    D40        357        628      0.474      0.247      0.249      0.106
# Speed: 0.6ms preprocess, 70.9ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_imgsz_400.quant.640/test_split_metrics.quant.640
#   ... took 302.0 sec
# pickling results to: 'runs_puhti/long_runs/150ep_imgsz_400.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_imgsz_400.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_imgsz_400 | Test image size: 640
#   [24/90] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_400"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5353.4±3089.0 MB/s, size: 382.4 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.5it/s 36.9s<0.2s
#                    all       3840       5430      0.534       0.47      0.478      0.223
#                    D00       1349       2626       0.55      0.481      0.491      0.253
#                    D10        744       1090      0.483      0.448      0.432      0.198
#                    D20        873       1086      0.589      0.574      0.601       0.28
#                    D40        357        628      0.513      0.379      0.388      0.162
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_imgsz_400/test_split_metrics.original.640
#   ... took 39.2 sec
# pickling results to: 'runs_puhti/long_runs/150ep_imgsz_400/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_imgsz_400/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_imgsz_480.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_imgsz_480.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_imgsz_480.quant.640 | Test image size: 640
#   [26/90] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_480.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_imgsz_480.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3757.7±1441.9 MB/s, size: 263.9 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.7it/s 5:01<0.2s
#                    all       3840       5430      0.526      0.392      0.397      0.185
#                    D00       1349       2626      0.511        0.4      0.412      0.206
#                    D10        744       1090      0.465      0.441      0.405      0.178
#                    D20        873       1086      0.643      0.456      0.494      0.229
#                    D40        357        628      0.486      0.271      0.276      0.128
# Speed: 0.6ms preprocess, 71.1ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_imgsz_480.quant.640/test_split_metrics.quant.640
#   ... took 302.7 sec
# pickling results to: 'runs_puhti/long_runs/150ep_imgsz_480.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_imgsz_480.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_imgsz_480 | Test image size: 640
#   [27/90] VALIDATING: "runs_puhti/long_runs/150ep_imgsz_480"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4909.8±2278.4 MB/s, size: 546.4 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.4it/s 37.3s<0.2s
#                    all       3840       5430      0.586        0.5      0.524      0.256
#                    D00       1349       2626      0.572      0.503      0.526      0.278
#                    D10        744       1090      0.554      0.483      0.493      0.229
#                    D20        873       1086      0.655      0.618      0.652      0.326
#                    D40        357        628      0.563      0.393      0.428      0.191
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_imgsz_480/test_split_metrics.original.640
#   ... took 39.6 sec
# pickling results to: 'runs_puhti/long_runs/150ep_imgsz_480/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_imgsz_480/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_lr0_half.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_lr0_half.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_lr0_half.quant.640 | Test image size: 640
#   [29/90] VALIDATING: "runs_puhti/long_runs/150ep_lr0_half.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_lr0_half.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3490.6±595.3 MB/s, size: 248.4 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.8it/s 5:01<0.1s
#                    all       3840       5430      0.565      0.437      0.448      0.214
#                    D00       1349       2626      0.569      0.421       0.45       0.23
#                    D10        744       1090      0.517      0.468      0.439        0.2
#                    D20        873       1086      0.653      0.526      0.553      0.278
#                    D40        357        628      0.521      0.334      0.347       0.15
# Speed: 0.6ms preprocess, 70.9ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_lr0_half.quant.640/test_split_metrics.quant.640
#   ... took 302.1 sec
# pickling results to: 'runs_puhti/long_runs/150ep_lr0_half.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_lr0_half.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_lr0_half | Test image size: 640
#   [30/90] VALIDATING: "runs_puhti/long_runs/150ep_lr0_half"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6163.4±1958.0 MB/s, size: 672.6 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.5it/s 37.0s<0.2s
#                    all       3840       5430      0.641      0.522      0.568      0.294
#                    D00       1349       2626      0.641      0.527      0.566      0.318
#                    D10        744       1090      0.614      0.531      0.565      0.279
#                    D20        873       1086      0.687      0.634      0.665      0.362
#                    D40        357        628      0.622      0.398      0.474      0.218
# Speed: 0.6ms preprocess, 7.5ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_lr0_half/test_split_metrics.original.640
#   ... took 39.3 sec
# pickling results to: 'runs_puhti/long_runs/150ep_lr0_half/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_lr0_half/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_no_drone.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_no_drone.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_no_drone.quant.640 | Test image size: 640
#   [32/90] VALIDATING: "runs_puhti/long_runs/150ep_no_drone.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_no_drone.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3098.1±1178.7 MB/s, size: 65.0 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 12.7it/s 5:02<0.1s
#                    all       3840       5430      0.593       0.44      0.474      0.243
#                    D00       1349       2626      0.591      0.436      0.475      0.253
#                    D10        744       1090      0.512      0.461      0.447      0.212
#                    D20        873       1086       0.73      0.534      0.614      0.341
#                    D40        357        628      0.541      0.328       0.36      0.165
# Speed: 0.6ms preprocess, 71.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_no_drone.quant.640/test_split_metrics.quant.640
#   ... took 303.7 sec
# pickling results to: 'runs_puhti/long_runs/150ep_no_drone.quant.640/test_split_metrics.quant.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_no_drone.quant.640/test_split_metrics.quant.640/images
# Testing model: runs_puhti/long_runs/150ep_no_drone | Test image size: 640
#   [33/90] VALIDATING: "runs_puhti/long_runs/150ep_no_drone"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3034.3±851.8 MB/s, size: 67.3 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 947.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 6.3it/s 38.2s<0.2s
#                    all       3840       5430      0.702      0.573      0.643       0.36
#                    D00       1349       2626      0.687      0.556      0.615      0.369
#                    D10        744       1090      0.653      0.546        0.6      0.307
#                    D20        873       1086       0.77      0.705      0.771      0.477
#                    D40        357        628      0.697      0.486      0.587      0.288
# Speed: 0.6ms preprocess, 7.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_no_drone/test_split_metrics.original.640
#   ... took 40.5 sec
# pickling results to: 'runs_puhti/long_runs/150ep_no_drone/test_split_metrics.original.640/metrics.pkl'
# moving images dir to: runs_puhti/long_runs/150ep_no_drone/test_split_metrics.original.640/images
# Testing model: runs_puhti/long_runs/150ep_normal.quant.320 | Test image size: 640
#
# Skipping model.val() for 150ep_normal.quant.320 with imgsz=640 due to image size mismatch.
#
# Testing model: runs_puhti/long_runs/150ep_normal.quant.640 | Test image size: 640
#   [35/90] VALIDATING: "runs_puhti/long_runs/150ep_normal.quant.640"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/long_runs/150ep_normal.quant.640/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3226.8±1302.6 MB/s, size: 231.1 KB)
# ...
#                    D00       1349       2626      0.313      0.252      0.199     0.0905
#                    D10        744       1090      0.297      0.261      0.205     0.0843
#                    D20        873       1086      0.378       0.32      0.277      0.133
#                    D40        357        628      0.259      0.137      0.104     0.0403
# Speed: 0.2ms preprocess, 18.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_adamw.quant.320/test_split_metrics.quant.320
#   ... took 95.7 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_adamw.quant.320/test_split_metrics.quant.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_adamw.quant.320/test_split_metrics.quant.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_adamw.quant.640 | Test image size: 320
#
# Skipping model.val() for opt_150ep_adamw.quant.640 with imgsz=320 due to image size mismatch.
#
# Testing model: runs_puhti/optimizers/opt_150ep_adamw | Test image size: 320
#   [81/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_adamw"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3497.5±737.9 MB/s, size: 75.5 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 14.7it/s 16.4s0.1s
#                    all       3840       5430      0.544      0.411       0.43      0.208
#                    D00       1349       2626      0.554      0.371        0.4        0.2
#                    D10        744       1090      0.507      0.414      0.432      0.207
#                    D20        873       1086      0.606      0.548       0.57      0.296
#                    D40        357        628      0.507      0.314      0.316       0.13
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_adamw/test_split_metrics.original.320
#   ... took 18.8 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_adamw/test_split_metrics.original.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_adamw/test_split_metrics.original.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.320 | Test image size: 320
#   [82/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.320"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.320/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 320, 320)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3468.0±1372.2 MB/s, size: 547.5 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 0% ──────────── 4/3840 11.9it/s 0.1s<5:22
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 41.4it/s 1:33<0.1ss
#                    all       3840       5430      0.348      0.137      0.126     0.0558
#                    D00       1349       2626      0.371      0.147      0.136     0.0597
#                    D10        744       1090      0.193      0.146     0.0937      0.043
#                    D20        873       1086      0.537       0.17      0.199     0.0918
#                    D40        357        628      0.291      0.086      0.077     0.0285
# Speed: 0.1ms preprocess, 18.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.320/test_split_metrics.quant.320
#   ... took 94.3 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.320/test_split_metrics.quant.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.320/test_split_metrics.quant.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_adamw_lr0.quant.640 | Test image size: 320
#
# Skipping model.val() for opt_150ep_adamw_lr0.quant.640 with imgsz=320 due to image size mismatch.
#
# Testing model: runs_puhti/optimizers/opt_150ep_adamw_lr0 | Test image size: 320
#   [84/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_adamw_lr0"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4877.6±2065.1 MB/s, size: 340.0 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 947.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 14.4it/s 16.7s0.2s
#                    all       3840       5430      0.555       0.42      0.438      0.213
#                    D00       1349       2626      0.576      0.387      0.411      0.207
#                    D10        744       1090      0.554      0.429       0.44      0.212
#                    D20        873       1086      0.602      0.536      0.571      0.303
#                    D40        357        628      0.487       0.33      0.328       0.13
# Speed: 0.2ms preprocess, 2.5ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_adamw_lr0/test_split_metrics.original.320
#   ... took 19.2 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_adamw_lr0/test_split_metrics.original.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_adamw_lr0/test_split_metrics.original.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_nadam.quant.320 | Test image size: 320
#   [85/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_nadam.quant.320"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/optimizers/opt_150ep_nadam.quant.320/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 320, 320)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3580.8±1440.8 MB/s, size: 387.7 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 42.4it/s 1:31<0.0ss
#                    all       3840       5430      0.355      0.141      0.149      0.066
#                    D00       1349       2626      0.251      0.176      0.144     0.0621
#                    D10        744       1090       0.33      0.194       0.17     0.0652
#                    D20        873       1086      0.489      0.144      0.205      0.104
#                    D40        357        628      0.348     0.0494      0.076     0.0333
# Speed: 0.1ms preprocess, 17.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_nadam.quant.320/test_split_metrics.quant.320
#   ... took 92.2 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_nadam.quant.320/test_split_metrics.quant.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_nadam.quant.320/test_split_metrics.quant.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_nadam.quant.640 | Test image size: 320
#
# Skipping model.val() for opt_150ep_nadam.quant.640 with imgsz=320 due to image size mismatch.
#
# Testing model: runs_puhti/optimizers/opt_150ep_nadam | Test image size: 320
#   [87/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_nadam"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3598.4±1874.4 MB/s, size: 219.9 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 15.7it/s 15.3s0.1s
#                    all       3840       5430      0.465      0.321      0.319      0.148
#                    D00       1349       2626      0.422      0.336      0.307      0.145
#                    D10        744       1090      0.484      0.322      0.333      0.144
#                    D20        873       1086       0.52      0.438      0.438      0.222
#                    D40        357        628      0.435      0.189      0.199     0.0793
# Speed: 0.2ms preprocess, 2.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_nadam/test_split_metrics.original.320
#   ... took 17.7 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_nadam/test_split_metrics.original.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_nadam/test_split_metrics.original.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_radam.quant.320 | Test image size: 320
#   [88/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_radam.quant.320"
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Loading runs_puhti/optimizers/opt_150ep_radam.quant.320/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 320, 320)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2835.1±572.9 MB/s, size: 61.1 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 1.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 0% ──────────── 5/3840 13.4it/s 0.1s<4:45
# /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/venv/lib/python3.10/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3840/3840 42.5it/s 1:30<0.0ss
#                    all       3840       5430      0.422       0.13      0.147     0.0627
#                    D00       1349       2626      0.349      0.143      0.137      0.056
#                    D10        744       1090      0.341      0.146      0.143     0.0525
#                    D20        873       1086      0.531      0.189      0.229       0.11
#                    D40        357        628      0.464     0.0428     0.0796     0.0322
# Speed: 0.1ms preprocess, 17.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_radam.quant.320/test_split_metrics.quant.320
#   ... took 91.9 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_radam.quant.320/test_split_metrics.quant.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_radam.quant.320/test_split_metrics.quant.320/images
# Testing model: runs_puhti/optimizers/opt_150ep_radam.quant.640 | Test image size: 320
#
# Skipping model.val() for opt_150ep_radam.quant.640 with imgsz=320 due to image size mismatch.
#
# Testing model: runs_puhti/optimizers/opt_150ep_radam | Test image size: 320
#   [90/90] VALIDATING: "runs_puhti/optimizers/opt_150ep_radam"
# Ultralytics 8.3.253 🚀 Python-3.10.12 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4018MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3761.1±1003.0 MB/s, size: 243.8 KB)
# val: Scanning /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/datasets/RDD2022_kaikki/labels/test.cache... 3840 images, 1446 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3840/3840 947.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 240/240 13.6it/s 17.6s0.2s
#                    all       3840       5430      0.469      0.297      0.301       0.14
#                    D00       1349       2626      0.454      0.298      0.289      0.138
#                    D10        744       1090      0.471      0.306      0.305      0.132
#                    D20        873       1086      0.507      0.409       0.41      0.209
#                    D40        357        628      0.445      0.174        0.2     0.0808
# Speed: 0.2ms preprocess, 2.6ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/optimizers/opt_150ep_radam/test_split_metrics.original.320
#   ... took 20.5 sec
# pickling results to: 'runs_puhti/optimizers/opt_150ep_radam/test_split_metrics.original.320/metrics.pkl'
# moving images dir to: runs_puhti/optimizers/opt_150ep_radam/test_split_metrics.original.320/images

# %% [markdown]
# ### STEP 2: Metrics processing

# %%
# TEST: get metrics.pkl from path
run_path = run_paths[0]
# metrics_pkl_path = run_path / TEST_METRICS_FOLDER / "metrics.pkl"
metrics_pkl_path = next(run_path.glob("**/metrics.pkl"), None)
print("pkl path: ", metrics_pkl_path)

if metrics_pkl_path is None:
    print("metrics.pkl not found")    

metrics_pkl_path.exists()
results: metrics.DetMetrics
with open(metrics_pkl_path, 'rb') as f:
    results = pickle.load(f)
results
# Out:
# pkl path:  runs_puhti/long_runs/150ep_bch_32.quant.320/test_split_metrics.quant.320/metrics.pkl
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7e3d51471360>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[          1,           1,     0.98113, ...,   0.0001542,  7.7099e-05,           0],
#        [          1,           1,           1, ...,  0.00016604,  8.3022e-05,           0],
#        [          1,           1,           1, ...,  0.00020069,  0.00010035,           0],
#        [          1,           1,           1, ...,  7.8163e-05,  3.9082e-05,           0]]), 'Recall', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[   0.069058,    0.069058,    0.069058, ...,           0,           0,           0],
#        [   0.069334,    0.069334,    0.069334, ...,           0,           0,           0],
#        [   0.074334,    0.074334,    0.074334, ...,           0,           0,           0],
#        [   0.041902,    0.041902,    0.041902, ...,           0,           0,           0]]), 'Confidence', 'F1'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[   0.036986,    0.036986,    0.036986, ...,           1,           1,           1],
#        [    0.03698,     0.03698,     0.03698, ...,           1,           1,           1],
#        [     0.0396,      0.0396,      0.0396, ...,           1,           1,           1],
#        [   0.022008,    0.022008,    0.022008, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[     0.5198,      0.5198,      0.5198, ...,           0,           0,           0],
#        [    0.55413,     0.55413,     0.55413, ...,           0,           0,           0],
#        [    0.60497,     0.60497,     0.60497, ...,           0,           0,           0],
#        [    0.43631,     0.43631,     0.43631, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: 0.10275072568009413
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.10364,     0.10037,     0.15535,    0.051637])
# names: {0: 'D00', 1: 'D10', 2: 'D20', 3: 'D40'}
# nt_per_class: array([2626, 1090, 1086,  628])
# nt_per_image: array([1349,  744,  873,  357])
# results_dict: {'metrics/precision(B)': 0.4123164868801138, 'metrics/recall(B)': 0.229828121131931, 'metrics/mAP50(B)': 0.2253497613214313, 'metrics/mAP50-95(B)': 0.10275072568009413, 'fitness': 0.10275072568009413}
# save_dir: PosixPath('/home/jaakko/kandi25/repo/2025_Kandi-RoadDefectDefetionInEdgeAI/ultralytics/runs/detect/runs_puhti/long_runs/150ep_bch_32.quant.320/test_split_metrics.quant.320')
# speed: {'preprocess': 0.1313224200809297, 'inference': 18.050254853975883, 'loss': 0.0009172862216170568, 'postprocess': 0.30317400087369606}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'

# %%
col_names = "Class mAP50 mAP50-95 Box-P Box-R Box-F1".split()
class_names = "mean D00 D10 D20 D40".split()

# construct data dict
new_col_names = [
    f"{col}_{cls}"
    for col in col_names if col != "Class"
    for cls in class_names
]
data: dict[str, list[pl.Float64]] = { k: [] for k in new_col_names }

metrics_pkl_paths = []
for run_path in run_paths:
    # metrics_pkl_path = run_path / TEST_METRICS_FOLDER / "metrics.pkl"
    for p in list(run_path.glob("**/metrics.pkl")):
        metrics_pkl_paths.append(p)

# print("pkl paths: ", metrics_pkl_paths)

# iterate
for metrics_pkl_path in metrics_pkl_paths:
        
    metrics_pkl_path.exists()
    results: metrics.DetMetrics
    with open(metrics_pkl_path, 'rb') as f:
        results = pickle.load(f)

    # get results df
    df = results.to_df()
    df = df[col_names]

    # compute mean row
    mean_row = (
        df
        .select(pl.exclude("Class").mean())
        .with_columns(pl.lit("mean").alias("Class"))
        .select(df.columns)   # reorder
    )
    df = pl.concat([df, mean_row], how="vertical")

    # add values to data{}
    for cls in class_names:
        cls_d = df.filter(pl.col("Class") == cls).to_dict(as_series=False)
        del cls_d["Class"]
        for k, v in cls_d.items():
            key = f"{k}_{cls}"
            data[key] = data.get(key, []) + v

# create new df and save csv
pkl_paths_short =  [str(p).replace(base_dir, "").split('/') for p in metrics_pkl_paths]
run_groups = [p[1] for p in pkl_paths_short]
run_names =  [p[2].split(".")[0] for p in pkl_paths_short]
run_quant = [p[3].split(".")[1] for p in pkl_paths_short]
run_imgsz = [int(p[3].split(".")[2]) for p in pkl_paths_short]
d = { "model_name": run_names, "run_group": run_groups, "quantized": run_quant, "imgsz": run_imgsz } | data # add run_name as col
df_all = pl.DataFrame(d)
df_all.write_csv("analytics/metrics_table.csv")
df_all
# Out:
# shape: (104, 29)
# ┌────────────┬────────────┬───────────┬───────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ model_name ┆ run_group  ┆ quantized ┆ imgsz ┆ … ┆ Box-F1_D00 ┆ Box-F1_D1 ┆ Box-F1_D2 ┆ Box-F1_D4 │
# │ ---        ┆ ---        ┆ ---       ┆ ---   ┆   ┆ ---        ┆ 0         ┆ 0         ┆ 0         │
# │ str        ┆ str        ┆ str       ┆ i64   ┆   ┆ f64        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆           ┆       ┆   ┆            ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═══════════╪═══════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 150ep_bch_ ┆ long_runs  ┆ quant     ┆ 320   ┆ … ┆ 0.30764    ┆ 0.2986    ┆ 0.3714    ┆ 0.20123   │
# │ 32         ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ 150ep_bch_ ┆ long_runs  ┆ quant     ┆ 640   ┆ … ┆ 0.4578     ┆ 0.45943   ┆ 0.51921   ┆ 0.33262   │
# │ 32         ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ 150ep_bch_ ┆ long_runs  ┆ original  ┆ 320   ┆ … ┆ 0.46687    ┆ 0.48759   ┆ 0.58101   ┆ 0.38531   │
# │ 32         ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ 150ep_bch_ ┆ long_runs  ┆ original  ┆ 640   ┆ … ┆ 0.5803     ┆ 0.56235   ┆ 0.65549   ┆ 0.48644   │
# │ 32         ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ 150ep_bch_ ┆ long_runs  ┆ quant     ┆ 320   ┆ … ┆ 0.31328    ┆ 0.33059   ┆ 0.43878   ┆ 0.2729    │
# │ 8          ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …         ┆ …     ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ opt_150ep_ ┆ optimizers ┆ original  ┆ 640   ┆ … ┆ 0.46863    ┆ 0.45134   ┆ 0.52258   ┆ 0.32582   │
# │ nadam      ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ opt_150ep_ ┆ optimizers ┆ quant     ┆ 320   ┆ … ┆ 0.20314    ┆ 0.20439   ┆ 0.27856   ┆ 0.07838   │
# │ radam      ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ opt_150ep_ ┆ optimizers ┆ quant     ┆ 640   ┆ … ┆ 0.3025     ┆ 0.30362   ┆ 0.32717   ┆ 0.16463   │
# │ radam      ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ opt_150ep_ ┆ optimizers ┆ original  ┆ 320   ┆ … ┆ 0.35981    ┆ 0.37135   ┆ 0.45252   ┆ 0.24968   │
# │ radam      ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# │ opt_150ep_ ┆ optimizers ┆ original  ┆ 640   ┆ … ┆ 0.46067    ┆ 0.44376   ┆ 0.50247   ┆ 0.32383   │
# │ radam      ┆            ┆           ┆       ┆   ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴───────────┴───────┴───┴────────────┴───────────┴───────────┴───────────┘
